# %%
# Regression Example With Boston Dataset: Baseline
import math
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from sklearn.preprocessing import LabelEncoder
from joblib import dump, load
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score, recall_score, precision_score, classification_report
# Splitting data into training/testing
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.preprocessing import MinMaxScaler

#Classifiers
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis


# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
multiclass = False
df = pd.read_csv("./audiology.standardized-discretized.csv")
#df = df.sample(frac=1)
cols = df.columns

# %%
X = df.iloc[:,0:len(cols)-1]
Y = df.iloc[:,len(cols)-1]

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state=42)

# %%
def model_report(model_name, model, model_scores):
    model_dict = {'model_name': model_name, 'model': model}
    model_dict['test_accuracy'] = model_scores['test_accuracy']
    model_dict['test_recall'] = model_scores['test_recall']
    model_dict['test_precision'] = model_scores['test_precision']
    return model_dict

# %%
def evaluate():
    # Instantiate the models
    all_models = []
    scoring_metrics = ['accuracy', 'precision', 'recall']
    scoring_metrics = {'accuracy': 'accuracy',
           'precision': make_scorer(precision_score, average='weighted'),
           'recall': make_scorer(recall_score, average='weighted'),
           #'f1': make_scorer(f1_score, average='weighted'),
           #'log_loss': 'neg_log_loss'
           }
    model_names = ['MLPClassifier', 'KNeighborsClassifier', 'SVC-Linear', 'SVC', \
                    'GaussianProcessClassifier', 'DecisionTreeClassifier', \
                    'RandomForestClassifier', 'AdaBoostClassifier', 'GaussianNB']
    model1 = MLPClassifier(alpha=1, max_iter=1000)
    model2 = KNeighborsClassifier(3)
    model3 = SVC(kernel="linear", C=0.025)
    model4 = SVC(gamma=2, C=1)
    model5 = GaussianProcessClassifier(1.0 * RBF(1.0))
    model6 = DecisionTreeClassifier(max_depth=5)
    model7 = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
    model8 = AdaBoostClassifier()
    model9 = GaussianNB()
    #model10 = QuadraticDiscriminantAnalysis()
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6, model7, model8, model9]):
        scoring = cross_validate(model, X, Y, cv=2, scoring=scoring_metrics, return_train_score=True, return_estimator=True)
        print(scoring)
        all_models.append(model_report(model_names[i], model, scoring))
    
    return all_models
models = evaluate()
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'fit_time': array([1.34761047, 1.43532372]), 'score_time': array([0.00639606, 0.00628686]), 'estimator': (MLPClassifier(alpha=1, max_iter=1000), MLPClassifier(alpha=1, max_iter=1000)), 'test_accuracy': array([0.45, 0.55]), 'train_accuracy': array([1.  , 0.99]), 'test_precision': array([0.52043308, 0.55219608]), 'train_precision': array([1.    , 0.9904]), 'test_recall': array([0.45, 0.55]), 'train_recall': array([1.  , 0.99])}
# {'fit_time': array([0.00386071, 0.00363398]), 'score_time': array([0.01289487, 0.01226425]), 'estimator': (KNeighborsClassifier(n_neighbors=3), KNeighborsClassifier(n_neighbors=3)), 'test_accuracy': array([0.08, 0.12]), 'train_accuracy': array([0.62, 0.6 ]), 'test_precision': array([0.0696    , 0.06934175]), 'train_precision': array([0.56067291, 0.55631493]), 'test_recall': array([0.08, 0.12]), 'train_recall': array([0.62, 0.6 ])}
# {'fit_time': array([0.0281868 , 0.02465272]), 'score_time': array([0.00651789, 0.00652337]), 'estimator': (SVC(C=0.025, kernel='linear'), SVC(C=0.025, kernel='linear')), 'test_accuracy': array([0.24, 0.35]), 'train_accuracy': array([0.48, 0.47]), 'test_precision': array([0.16492424, 0.184733  ]), 'train_precision': array([0.32582123, 0.38816667]), 'test_recall': array([0.24, 0.35]), 'train_recall': array([0.48, 0.47])}
# {'fit_time': array([0.01262212, 0.01157355]), 'score_time': array([0.00732851, 0.007658  ]), 'estimator': (SVC(C=1, gamma=2), SVC(C=1, gamma=2)), 'test_accuracy': array([0.24, 0.24]), 'train_accuracy': array([1., 1.]), 'test_precision': array([0.0576, 0.0576]), 'train_precision': array([1., 1.]), 'test_recall': array([0.24, 0.24]), 'train_recall': array([1., 1.])}
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# {'fit_time': array([35.6554718 , 23.22678971]), 'score_time': array([1.48157001, 1.12011027]), 'estimator': (GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1)), GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))), 'test_accuracy': array([0.03, 0.22]), 'train_accuracy': array([0.14, 0.32]), 'test_precision': array([0.01647059, 0.09178571]), 'train_precision': array([0.05955982, 0.16530702]), 'test_recall': array([0.03, 0.22]), 'train_recall': array([0.14, 0.32])}
# {'fit_time': array([0.00416517, 0.00362039]), 'score_time': array([0.01559591, 0.0055027 ]), 'estimator': (DecisionTreeClassifier(max_depth=5), DecisionTreeClassifier(max_depth=5)), 'test_accuracy': array([0.48, 0.64]), 'train_accuracy': array([0.8 , 0.86]), 'test_precision': array([0.54973684, 0.52388736]), 'train_precision': array([0.76906746, 0.76707143]), 'test_recall': array([0.48, 0.64]), 'train_recall': array([0.8 , 0.86])}
# {'fit_time': array([0.01815557, 0.01817012]), 'score_time': array([0.00659633, 0.00616765]), 'estimator': (RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10), RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10)), 'test_accuracy': array([0.43, 0.53]), 'train_accuracy': array([0.71, 0.71]), 'test_precision': array([0.38204334, 0.50932143]), 'train_precision': array([0.70714286, 0.71412403]), 'test_recall': array([0.43, 0.53]), 'train_recall': array([0.71, 0.71])}
# {'fit_time': array([0.08338737, 0.0808506 ]), 'score_time': array([0.01794934, 0.01625395]), 'estimator': (AdaBoostClassifier(), AdaBoostClassifier()), 'test_accuracy': array([0.3 , 0.49]), 'train_accuracy': array([0.34, 0.57]), 'test_precision': array([0.29438596, 0.28830769]), 'train_precision': array([0.19013268, 0.35361111]), 'test_recall': array([0.3 , 0.49]), 'train_recall': array([0.34, 0.57])}
# {'fit_time': array([0.00502443, 0.00493622]), 'score_time': array([0.00676584, 0.00654054]), 'estimator': (GaussianNB(), GaussianNB()), 'test_accuracy': array([0.69, 0.68]), 'train_accuracy': array([0.97, 1.  ]), 'test_precision': array([0.71804654, 0.63859524]), 'train_precision': array([0.98285714, 1.        ]), 'test_recall': array([0.69, 0.68]), 'train_recall': array([0.97, 1.  ])}
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(("The least populated class in y has only %d"
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def round_ave(number):
    return np.round(np.average(number), decimals=3)
for model in models:
    print("Model Name: " + str(model['model_name']))
    print("Model accuracy: " + str(round_ave(model['test_accuracy'])))
    print("Model recall: " + str(round_ave(model['test_recall'])))
    print("Model precision: " + str(round_ave(model['test_precision'])))
    print("\n")
# Out:
# Model Name: MLPClassifier
# Model accuracy: 0.5
# Model recall: 0.5
# Model precision: 0.536
#
#
# Model Name: KNeighborsClassifier
# Model accuracy: 0.1
# Model recall: 0.1
# Model precision: 0.069
#
#
# Model Name: SVC-Linear
# Model accuracy: 0.295
# Model recall: 0.295
# Model precision: 0.175
#
#
# Model Name: SVC
# Model accuracy: 0.24
# Model recall: 0.24
# Model precision: 0.058
#
#
# Model Name: GaussianProcessClassifier
# Model accuracy: 0.125
# Model recall: 0.125
# Model precision: 0.054
#
#
# Model Name: DecisionTreeClassifier
# Model accuracy: 0.56
# Model recall: 0.56
# Model precision: 0.537
#
#
# Model Name: RandomForestClassifier
# Model accuracy: 0.48
# Model recall: 0.48
# Model precision: 0.446
#
#
# Model Name: AdaBoostClassifier
# Model accuracy: 0.395
# Model recall: 0.395
# Model precision: 0.291
#
#
# Model Name: GaussianNB
# Model accuracy: 0.685
# Model recall: 0.685
# Model precision: 0.678
