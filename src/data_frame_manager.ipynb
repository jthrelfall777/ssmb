# %%
import sys
sys.path.append("./")
from results import Experiment_Results

# %%
#Create blank dataframe
erc = Experiment_Results()
erc.create_df()
erc.save_df('../results/pd_results_dataframe.pkl')

# %%
#Save dataframe as excel
erc = Experiment_Results()
erc.load_df('../results/pd_results_dataframe.pkl')
erc.save_df_as_excel('../results/results.xlsx')

# %%
erc = Experiment_Results()
erc.load_df('../results/pd_results_dataframe.pkl')
df = erc.get_df()
df
# Out:
#                           dt                            experiment_name  \
# 0 2021-08-27 13:32:53.163733  acute-inflammations-diagnosis-discretized
# 1 2021-08-27 13:32:53.181713  acute-inflammations-diagnosis-discretized
# 2 2021-08-27 13:32:53.196646  acute-inflammations-diagnosis-discretized
#
#        model_name  graph  p_value  refset_size  before_limit_refset_size  \
# 0  scatter search      1     0.05           10                        42
# 1  scatter search      2     0.05           10                        42
# 2  scatter search      3     0.05           10                        42
#
#    vertices  edge  runtime  ...  precision    TN    FN   TP   FP       NPV  \
# 0         5     4  967.795  ...        0.0  70.0  50.0  0.0  0.0  0.583333
# 1         6     5  450.325  ...        0.0  70.0  50.0  0.0  0.0  0.583333
# 2         5     4  263.672  ...        0.0  70.0  50.0  0.0  0.0  0.583333
#
#    PPV  sensitivity  specificity  PRC
# 0  NaN          0.0          1.0  0.0
# 1  NaN          0.0          1.0  0.0
# 2  NaN          0.0          1.0  0.0
#
# [3 rows x 26 columns]
